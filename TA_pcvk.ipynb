# %% [markdown]
# <a href="https://colab.research.google.com/github/henrymic0408/PCVK_Genap_2021/blob/main/TA_pcvk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import math
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('drive/MyDrive/TA_PCVK/bandeng2.png')
plt.imshow(img)
img.shape
# Out:
# (120, 240, 3)

# %%
img[:,:,0] #blue
# Out:
# array([[ 26,  26,  26, ..., 174, 175, 174],
#        [ 17,  17,  17, ..., 169, 169, 168],
#        [ 18,  18,  18, ..., 171, 171, 169],
#        ...,
#        [ 71,  67,  62, ..., 156, 170, 168],
#        [ 70,  68,  64, ..., 158, 172, 172],
#        [ 64,  67,  67, ..., 154, 170, 168]], dtype=uint8)

# %%
img[:,:,1] #green
# Out:
# array([[ 29,  29,  29, ..., 175, 175, 172],
#        [ 20,  20,  20, ..., 170, 169, 167],
#        [ 21,  21,  21, ..., 172, 171, 168],
#        ...,
#        [ 88,  84,  79, ..., 164, 176, 172],
#        [ 87,  85,  81, ..., 165, 179, 176],
#        [ 80,  84,  84, ..., 160, 175, 172]], dtype=uint8)

# %%
img[:,:,2] #red
# Out:
# array([[ 27,  27,  27, ..., 167, 166, 164],
#        [ 18,  18,  18, ..., 161, 160, 159],
#        [ 19,  19,  19, ..., 163, 162, 159],
#        ...,
#        [ 85,  81,  76, ..., 154, 168, 166],
#        [ 84,  82,  78, ..., 155, 171, 170],
#        [ 77,  81,  81, ..., 151, 168, 166]], dtype=uint8)

# %%
hasil = []

for x in range(0,img.shape[0]):
    row = []
    for y in range(0, img.shape[1]):
        blue = img[x,y,0] - 35
        green = img[x,y,1] - 35
        red = img[x,y,2] - 160
        blue = blue**2
        green = green**2
        red = red**2
        tambahRGB = blue + green + red
        akar = math.sqrt(tambahRGB)
        if akar > 55:
            row.append(0)
        else:
            row.append(1)
    hasil.append(row)

segar = True
for i in hasil:
    for j in i:
        if j > 0:
            segar = False
            break;
if segar:
    print("ikan Segar")
else:
    print("ikan Tidak Segar")
# Out:
# ikan Segar
